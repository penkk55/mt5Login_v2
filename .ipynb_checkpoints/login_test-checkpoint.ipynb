# %%
# doc---> https://www.mql5.com/en/docs/integration/python_metatrader5
import MetaTrader5 as mt5
import pandas as pd
import plotly.express as px
from datetime import datetime
# display data on the MetaTrader 5 package
print("MetaTrader5 package author: ",mt5.__author__)
print("MetaTrader5 package version: ",mt5.__version__)
# Out:
# MetaTrader5 package author:  MetaQuotes Ltd.
# MetaTrader5 package version:  5.0.43

# %%
# open mt5 ---
mt5.initialize()
# Out:
# True

# %%
# login ??

login = 61121787
password='kc+t!CA@bJc2pUN'
server ='Pepperstone-Demo'
mt5.login(login,password,server)
# Out:
# True

# %%
account_info = mt5.account_info()
print(account_info)

login_number =account_info.login
balance = account_info.balance
equity =account_info.equity

print('----')
print('login : ',login)
print('balance : ',balance)
print('equity : ',equity)
# Out:
# AccountInfo(login=61121787, trade_mode=0, leverage=200, limit_orders=500, margin_so_mode=0, trade_allowed=True, trade_expert=True, margin_mode=2, currency_digits=2, fifo_close=False, balance=59943.8, credit=0.0, profit=0.0, equity=59943.8, margin=0.0, margin_free=59943.8, margin_level=0.0, margin_so_call=90.0, margin_so_so=50.0, margin_initial=0.0, margin_maintenance=0.0, assets=0.0, liabilities=0.0, commission_blocked=0.0, name='penk naja', server='Pepperstone-Demo', currency='USD', company='Pepperstone Markets Limited')
# ----
# login :  61121787
# balance :  59943.8
# equity :  59943.8

# %%
num_symbols = mt5.symbols_total()

num_symbols
# Out:
# 1227

# %%
# get all symbols and specification
symbols = mt5.symbols_get()
symbols
# Out:
# (SymbolInfo(custom=False, chart_mode=0, select=True, visible=True, session_deals=0, session_buy_orders=0, session_sell_orders=0, volume=0, volumehigh=0, volumelow=0, time=1673049299, digits=5, spread=12, spread_float=True, ticks_bookdepth=0, trade_calc_mode=0, trade_mode=4, start_time=0, expiration_time=0, trade_stops_level=0, trade_freeze_level=0, trade_exemode=2, swap_mode=1, swap_rollover3days=3, margin_hedged_use_leg=False, expiration_mode=15, filling_mode=2, order_mode=127, order_gtc_mode=0, option_mode=0, option_right=0, bid=0.68756, bidhigh=0.68868, bidlow=0.6722, ask=0.68768, askhigh=0.6887, asklow=0.67224, last=0.0, lasthigh=0.0, lastlow=0.0, volume_real=0.0, volumehigh_real=0.0, volumelow_real=0.0, option_strike=0.0, point=1e-05, trade_tick_value=1.0, trade_tick_value_profit=1.0, trade_tick_value_loss=1.0, trade_tick_size=1e-05, trade_contract_size=100000.0, trade_accrued_interest=0.0, trade_face_value=0.0, trade_liquidity_rate=0.0, volume_min=0.01, volume_max=100.0, volume
# ...

# %%
# get symbol specification
symbol_info = mt5.symbol_info("XAUUSD")._asdict()
# print(symbol_info)
symbol_info
# Out:
# {'custom': False,
#  'chart_mode': 0,
#  'select': True,
#  'visible': True,
#  'session_deals': 0,
#  'session_buy_orders': 0,
#  'session_sell_orders': 0,
#  'volume': 0,
#  'volumehigh': 0,
#  'volumelow': 0,
#  'time': 1673049295,
#  'digits': 2,
#  'spread': 46,
#  'spread_float': True,
#  'ticks_bookdepth': 0,
#  'trade_calc_mode': 0,
#  'trade_mode': 4,
#  'start_time': 0,
#  'expiration_time': 0,
#  'trade_stops_level': 0,
#  'trade_freeze_level': 0,
#  'trade_exemode': 2,
#  'swap_mode': 1,
#  'swap_rollover3days': 3,
#  'margin_hedged_use_leg': False,
#  'expiration_mode': 15,
#  'filling_mode': 2,
#  'order_mode': 127,
#  'order_gtc_mode': 0,
#  'option_mode': 0,
#  'option_right': 0,
#  'bid': 1866.45,
#  'bidhigh': 1869.8,
#  'bidlow': 1829.33,
#  'ask': 1866.91,
#  'askhigh': 1870.03,
#  'asklow': 1831.2,
#  'last': 0.0,
#  'lasthigh': 0.0,
#  'lastlow': 0.0,
#  'volume_real': 0.0,
#  'volumehigh_real': 0.0,
#  'volumelow_real': 0.0,
#  'option_strike': 0.0,
# ...

# %%
# get current symbol price
symbol_price = mt5.symbol_info("XAUUSD")._asdict()
symbol_price
# Out:
# {'custom': False,
#  'chart_mode': 0,
#  'select': True,
#  'visible': True,
#  'session_deals': 0,
#  'session_buy_orders': 0,
#  'session_sell_orders': 0,
#  'volume': 0,
#  'volumehigh': 0,
#  'volumelow': 0,
#  'time': 1673049295,
#  'digits': 2,
#  'spread': 46,
#  'spread_float': True,
#  'ticks_bookdepth': 0,
#  'trade_calc_mode': 0,
#  'trade_mode': 4,
#  'start_time': 0,
#  'expiration_time': 0,
#  'trade_stops_level': 0,
#  'trade_freeze_level': 0,
#  'trade_exemode': 2,
#  'swap_mode': 1,
#  'swap_rollover3days': 3,
#  'margin_hedged_use_leg': False,
#  'expiration_mode': 15,
#  'filling_mode': 2,
#  'order_mode': 127,
#  'order_gtc_mode': 0,
#  'option_mode': 0,
#  'option_right': 0,
#  'bid': 1866.45,
#  'bidhigh': 1869.8,
#  'bidlow': 1829.33,
#  'ask': 1866.91,
#  'askhigh': 1870.03,
#  'asklow': 1831.2,
#  'last': 0.0,
#  'lasthigh': 0.0,
#  'lastlow': 0.0,
#  'volume_real': 0.0,
#  'volumehigh_real': 0.0,
#  'volumelow_real': 0.0,
#  'option_strike': 0.0,
# ...

# %%
# OPEN HIGHT LOW DAtA ohlc
ohlc_data = pd.DataFrame(mt5.copy_rates_range("XAUUSD",
                                            mt5.TIMEFRAME_M15,
                                            datetime(2022,1,1),
                                            datetime.now()))
fig= px.line(ohlc_data, x=ohlc_data['time'], y=ohlc_data['close'])
fig.show()

ohlc_data
# Out:
# <div>                            <div id="1b48d053-bebf-4818-ac51-fabb58d06668" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1b48d053-bebf-4818-ac51-fabb58d06668")) {                    Plotly.newPlot(                        "1b48d053-bebf-4818-ac51-fabb58d06668",                        [{"hovertemplate":"time=%{x}<br>close=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":[1640970000,1640970900,1640971800,1640972700,1640973600,1640974500,1640975400,1640976300,1640977200,1640978100,1640979000,1640979900,1640980800,1640981700,1640982600,1640983500,1640984400,1640985300,1640986200,1640987100,1640988000,1640988900,1640989800,1640990700,16409916
# ...

# %%
import pytz
# request tick data
tick_data = pd.DataFrame(mt5.copy_ticks_range("XAUUSD",
                                            datetime(2022,1,1),
                                            datetime.now(),
                                            mt5.COPY_TICKS_ALL))
# timezone = pytz.timezone("Etc/UTC")
# utc_from = datetime(2020, 1, 10, tzinfo=timezone)
# utc_to = datetime(2020, 1, 11, tzinfo=timezone)
# ticks = mt5.copy_ticks_range("AUDUSD", utc_from, utc_to, mt5.COPY_TICKS_ALL)

fig= px.line(tick_data, x=tick_data['time'], y=[tick_data['bid'],tick_data['ask']])
# fig= px.line(ticks, x=ticks['time'], y=[ticks['bid'],ticks['ask']])

# fig = px.line(tick_data, x= tick_data['time'], y= tick_data['asj'])
# fig.show()
# fig1 = px.line(tick_data, x='time', y='bid')
# fig1.show()

# fig2 = px.line(tick_data, x='time', y='ask')
# fig2.show()

# tick_data['midpoint'] = (tick_data['bid'] + tick_data['ask']) / 2
# fig = px.line(tick_data, x='time', y='midpoint')
# fig.show()
# ticks
tick_data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[118], line 12
#       3 tick_data = pd.DataFrame(mt5.copy_ticks_range("XAUUSD",
#       4                                             datetime(2022,1,1),
#       5                                             datetime.now(),
#       6                                             mt5.COPY_TICKS_ALL))
#       7 # timezone = pytz.timezone("Etc/UTC")
#       8 # utc_from = datetime(2020, 1, 10, tzinfo=timezone)
#       9 # utc_to = datetime(2020, 1, 11, tzinfo=timezone)
#      10 # ticks = mt5.copy_ticks_range("AUDUSD", utc_from, utc_to, mt5.COPY_TICKS_ALL)
# ---> 12 fig= px.line(tick_data, x=tick_data['time'], y=[tick_data['bid'],tick_data['ask']])
#      13 # fig= px.line(ticks, x=ticks['time'], y=[ticks['bid'],ticks['ask']])
#      14
#      15 # fig = px.line(tick_data, x= tick_data['time'], y= tick_data['asj'])
#    (...)
# ...

# %%
# total number of orders
num_orders = mt5.orders_total()
num_orders
# Out:
# 0

# %%
# lists of orders 
orders =mt5.orders_get()
orders
# Out:
# ()

# %%
# total numbers of position
num_positions =mt.positions_total()
num_positions
# Out:
# 0

# %%
# list of position
positions =mt5.positions_get()
positions
# Out:
# ()

# %%
# number of history orders
num_order_history = mt5.history_orders_total(datetime(2022,1,1),
                                                   datetime.now())

num_order_history
# Out:
# 296

# %%
# lsit of history order 
order_history = mt5.history_deals_get(datetime(2022,1,1),
                                                   datetime.now())
order_history
# Out:
# (TradeDeal(ticket=52236898, order=0, time=1671213794, time_msc=1671213794298, type=2, entry=0, magic=0, position_id=0, reason=0, volume=0.0, price=0.0, commission=0.0, swap=0.0, profit=50000.0, fee=0.0, symbol='', comment='Demo Deposit', external_id=''),
#  TradeDeal(ticket=52260751, order=67419691, time=1671421329, time_msc=1671421329566, type=0, entry=0, magic=0, position_id=67419691, reason=0, volume=0.01, price=1794.92, commission=0.0, swap=0.0, profit=0.0, fee=0.0, symbol='XAUUSD', comment='', external_id=''),
#  TradeDeal(ticket=52260767, order=0, time=1671421411, time_msc=1671421411361, type=2, entry=0, magic=0, position_id=0, reason=0, volume=0.0, price=0.0, commission=0.0, swap=0.0, profit=10000.0, fee=0.0, symbol='', comment='Demo Deposit', external_id=''),
# ...

# %%
# number of history deals
num_deal_history = mt5.history_deals_total(datetime(2022,1,1),
                                                   datetime.now())
num_deal_history
# Out:
# 298

# %%
# list of history deals
deal_history = mt5.history_deals_get(datetime(2022,1,1),
                                                   datetime.now())
deal_history
# Out:
# (TradeDeal(ticket=52236898, order=0, time=1671213794, time_msc=1671213794298, type=2, entry=0, magic=0, position_id=0, reason=0, volume=0.0, price=0.0, commission=0.0, swap=0.0, profit=50000.0, fee=0.0, symbol='', comment='Demo Deposit', external_id=''),
#  TradeDeal(ticket=52260751, order=67419691, time=1671421329, time_msc=1671421329566, type=0, entry=0, magic=0, position_id=67419691, reason=0, volume=0.01, price=1794.92, commission=0.0, swap=0.0, profit=0.0, fee=0.0, symbol='XAUUSD', comment='', external_id=''),
#  TradeDeal(ticket=52260767, order=0, time=1671421411, time_msc=1671421411361, type=2, entry=0, magic=0, position_id=0, reason=0, volume=0.0, price=0.0, commission=0.0, swap=0.0, profit=10000.0, fee=0.0, symbol='', comment='Demo Deposit', external_id=''),
# ...

# %%
# send request https://www.mql5.com/en/docs/integration/python_metatrader5/mt5ordersend_py

symbol = "XAUUSD"
lot = 0.1
point = mt5.symbol_info(symbol).point
price = mt5.symbol_info_tick(symbol).ask
deviation = 20

request = {
    "action": mt5.TRADE_ACTION_DEAL,
    "symbol": "XAUUSD", #symbols
    "volume": 2.0, #lot
    "type": mt5.ORDER_TYPE_BUY,
    "price": price,
    "sl": price - 100 * point,
    "tp": price + 100 * point,
    "deviation": deviation, #integer
    "magic": 234000,#integer
    "comment": "python script open",
    "type_time": mt5.ORDER_TIME_GTC,
#     "type_filling": mt5.ORDER_FILLING_RETURN,
    "type_filling": mt5.ORDER_FILLING_IOC,
}
# send a trading request
order = mt5.order_send(request)
print(order)
# Out:
# OrderSendResult(retcode=10018, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='Market closed', request_id=1, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='XAUUSD', volume=2.0, price=1866.91, stoplimit=0.0, sl=1865.91, tp=1867.91, deviation=20, type=0, type_filling=1, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))

# %%
# close position

# create a close request
position_id=order.order
price=mt5.symbol_info_tick(symbol).bid
deviation=20
request={
    "action": mt5.TRADE_ACTION_DEAL,
    "symbol": symbol,
    "volume": lot,
    "type": mt5.ORDER_TYPE_SELL,
    "position": position_id, #select posotion wanted to close look at position list
    "price": price,
    "deviation": deviation,
    "magic": 234000,
    "comment": "python script close",
    "type_time": mt5.ORDER_TIME_GTC,
    "type_filling": mt5.ORDER_FILLING_RETURN,
}
order = mt5.order_send(request)
print(order)

# send a trading request
# Out:
# OrderSendResult(retcode=10030, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='Unsupported filling mode', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=234000, order=0, symbol='XAUUSD', volume=0.1, price=1866.45, stoplimit=0.0, sl=0.0, tp=0.0, deviation=20, type=1, type_filling=2, type_time=0, expiration=0, comment='python script close', position=0, position_by=0))
